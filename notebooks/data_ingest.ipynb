# %% [markdown]
# # Data Ingest Pipeline
#
# ## Raw
#
# The raw landing zone will include various datasets, data formats and we will have to find a way to normalize all of the different types of inputs into a standard format (images)
#
# - Image
#
# - Video
#
# ## Metadata
#
# Prior to loading all of the images/videos into the dataset we need to build a metadata mapping list for the known pollen grain slides. The goal is to build a robust enough library of pollen types so that data annotation becomes automated reducing the need to manually label each pollen slide. I think having a binary classification system for detecting pollen grains would help for the initial annotation process. Once the slides are annotated these "unknown" pollen types can be labeled by a professional. Our goal is to reduce the amount of manual intervention required to annotate and count pollen grains on microscope slides.
#
# ## Dataset
#
# The dataset will be the normalized images in jpg format. The images will be stored under
# - POLLEN/{FAMILY}/{GENUS}/{SPECIES}/{YEAR_COLLECTED}/{MONTH_COLLECTED}

# %%
metadata_url = '../data/metadata/pollenlibrary/full.json'

import pandas as pd

metadata_df = pd.read_json(metadata_url)

# %%
metadata_df = metadata_df[['id','friendly_name', 'allergy_level', 'pollination_season_text']]
metadata_df[['family', 'genus', 'species']] = metadata_df['id'].str.split('_', expand=True)
metadata_df
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_115500\331649850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_df[['family', 'genus', 'species']] = metadata_df['id'].str.split('_', expand=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_115500\331649850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_df[['family', 'genus', 'species']] = metadata_df['id'].str.split('_', expand=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_115500\331649850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_df[['family', 'genus', 'species']] = metadata_df['id'].str.split('_', expand=True)
#                                                id  \
# 0                hypericaceae_hypericum_calycinum
# 1     cupressaceae_callitropsisoerst_nootkatensis
# 2                   rosaceae_cercocarpus_montanus
# 3                        fabaceae_medicago_sativa
# 4                        fagaceae_castanea_pumila
# ...                                           ...
# 1000                cyperaceae_cyperus_flavescens
# 1001                   poaceae_sorghastrum_nutans
# 1002               fabaceae_melilotus_officinalis
# 1003            asteraceae_baccharis_pteronioides
# 1004                   salicaceae_salix_taxifolia
#
#                      friendly_name  allergy_level pollination_season_text  \
# 0                    Aaron's-Beard              0         Summer to Fall.
# 1                     Alaska-Cedar              2                 Spring.
# 2     Alder-Leaf Mountain-Mahogany              1          all year long.
# 3                          Alfalfa              2         Spring to Fall.
# 4              Allegheny-Chinkapin              1       Winter to Summer.
# ...                            ...            ...                     ...
# 1000             Yellow Flat Sedge              1       Summer to Winter.
# 1001           Yellow Indian Grass              1         Summer to Fall.
# 1002           Yellow Sweet-Clover              1         Spring to Fall.
# 1003                Yerba-de-Pasmo              3       Spring to Summer.
# 1004               Yew-Leaf Willow              3                 Spring.
#
#             family              genus       species
# 0     hypericaceae          hypericum     calycinum
# 1     cupressaceae  callitropsisoerst  nootkatensis
# 2         rosaceae        cercocarpus      montanus
# 3         fabaceae           medicago        sativa
# 4         fagaceae           castanea        pumila
# ...            ...                ...           ...
# 1000    cyperaceae            cyperus    flavescens
# 1001       poaceae        sorghastrum        nutans
# 1002      fabaceae          melilotus   officinalis
# 1003    asteraceae          baccharis  pteronioides
# 1004    salicaceae              salix     taxifolia
#
# [1005 rows x 7 columns]

# %%
metadata_df.family.value_counts()[-20:]
# Out:
# family
# papaveraceae                  2
# hamamelidaceae                2
# araliaceae                    1
# dennstaedtiaceae              1
# altingiaceae                  1
# haloragaceae                  1
# juncaginaceae                 1
# lycopodiaceae                 1
# scheuchzeriaceaefrudolphi1    1
# cistaceae                     1
# picramniaceae                 1
# onagraceae                    1
# zygophyllaceae                1
# ginkgoaceae                   1
# simmondsiaceae                1
# nyssaceae                     1
# sarcobataceaebehnke           1
# buxaceae                      1
# amaryllidaceae                1
# liliaceae                     1
# Name: count, dtype: int64

# %%
metadata_df.loc[metadata_df.family=='liliaceae']
# Out:
#                                id friendly_name  allergy_level  \
# 897  liliaceae_lilium_longiflorum  Trumpet Lily              0
#
#     pollination_season_text     family   genus      species
# 897                 Summer.  liliaceae  lilium  longiflorum

# %%
metadata_df.loc[metadata_df.allergy_level>1].genus.value_counts()
# Out:
# genus
# quercus      45
# artemisia    41
# salix        26
# ambrosia     23
# acer         15
#              ..
# tripsacum     1
# arundo        1
# neokochia     1
# cannabis      1
# myrica        1
# Name: count, Length: 91, dtype: int64
